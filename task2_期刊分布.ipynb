# %%
import pandas as pd

# %%
journals = [
    "Pharmazie",
    "Molecular Therapy-Nucleic Acids",
    "Experimental and Molecular Pathology",
    "Journal of Cellular and Molecular Medicine",
    "Molecular Medicine Reports",
    "Journal of International Medical Research",
    "Journal of Cancer",
    "Medical Science Monitor",
    "Aging-US",
    "OncoTargets and Therapy",
    "Cancer Management and Research",
    "Cancer CellInternational",
    "World Journal of Clinical Cases",
    "Annals of Palliative Medicine",
    "International Journal of General Medicine",
    "Frontiers in Medicine",
    "Journal of Personalized Medicine",
    "Healthcare",
    "Diagnostics",
    "Vaccines",
    "Complexity",
    "Shock and Vibration",
    "Advances in Civil Engineering",
    "Biomedicines",
    "Microprocessors and Microsystems",
    "Scientific Programming",
    "BioFactors",
    "Mitochondrial DNA Part B-Resources",
    "Frontiers in Molecular Biosciences",
    "Frontiers in Cell and Developmental Biology",
    "Life-Basel",
    "Biology-Basel",
    "Discrete Dynamics in Nature and Society",
    "AIMS Mathematics",
    "Journal of Mathematics",
    "INORGANIC AND NANO-METAL CHEMISTRY",
    "JOURNAL OF STRUCTURAL CHEMISTRY",
    "INTERNATIONAL JOURNAL OF ELECTROCHEMICAL SCIENCE",
    "MICROPROCESSORS AND MICROSYSTEMS",
    "FRONTIERS IN ENVIRONMENTAL SCIENCE",
    "INTERNATIONAL JOURNAL OF CONTROL AUTOMATION AND SYSTEMS",
    "MOBILE INFORMATION SYSTEMS",
    "ECONOMIC RESEARCH-EKONOMSKA ISTRAZIVANJA",
    "FOOD SCIENCE AND TECHNOLOGY",
    "JOURNAL OF ENVIRONMENTAL AND PUBLIC HEALTH",
    "PHARMAZIE",
    "PSYCHIATRIA DANUBINA",
    "ACTA MEDICA MEDITERRANEA",
    "JOURNAL OF BIOMATERIALS AND TISSUE ENGINEERING",
    "JOURNAL OF CLINICAL LABORATORY ANALYSISWORLD",
    "JOURNAL OF CLINICAL CASES",
    "AMERICAN JOURNAL OF TRANSLATIONAL RESEARCH",
    "FRONTIERS IN SURGERY",
    "TEXTILE RESEARCH JOURNAL",
    "GEOFLUIDS",
    "FRONTIERS IN EARTH SCIENCE",
    "JOURNAL OF INDUSTRIAL AND MANAGEMENT OPTIMIZATION",
    "MATHEMATICAL PROBLEMS IN ENGINEERING",
    "AEROSPACE",
    "BUILDINGS",
    "COMPUTATIONAL AND MATHEMATICAL METHODS IN MEDICINE",
    "ENERGY REPORTS",
    "MACHINES",
    "Metals",
    "Coatings",
    "Materials",
    "JOURNAL OF NANOSCIENCE AND NANOTECHNOLOGY",
    "Minerals",
    "Atmosphere",
    "Artificial Cells Nanomedicine and Biotechnology",
    "Advances in Civil Engineering",
    "INTERNATIONAL JOURNAL OF ENERGY RESEARCH",
    "MATHEMATICAL PROBLEMS IN ENGINEERING",
    "SENSORS",
    "Energies",
    "Applied Sciences-Basel",
    "Polymers",
    "Electronics",
    "Processes",
    "International Journal of Electrochemical Science",
    "Catalysts",
    "MOLECULES",
    "NATURAL PRODUCT RESEARCH",
    "ZEITSCHRIFT FUR KRISTALLOGRAPHIE-NEW CRYSTAL STRUCTURES",
    "Sustainability",
    "Water",
    "IEEE Access",
    "Agronomy-Basel",
    "JOURNAL OF CELLULAR BIOCHEMISTRY",
    "JOURNAL OF CELLULAR PHYSIOLOGY",
    "BIOSCIENCE REPORTS",
    "Biomed Research International",
    "BIOFACTORS",
    "Plants-Basel",
    "Cells",
    "Boundary Value Problems",
    "Advances in Difference Equations",
    "JOURNAL OF INEQUALITIES AND APPLICATIONS",
    "Mathematics",
    "European Review for Medical and Pharmacological Sciences",
    "International Journal of Clinical and Experimental Pathology",
    "MEDICINE",
    "International Journal of Clinical and Experimental Medicine",
    "BIOMEDICINE & PHARMACOTHERAPY",
    "EXPERIMENTAL AND MOLECULAR PATHOLOGY",
    "BRAZILIAN JOURNAL OF MEDICAL AND BIOLOGICAL RESEARCH",
    "Cancer Biomarkers",
    "INTERNATIONAL JOURNAL OF IMMUNOPATHOLOGY AND PHARMACOLOGY",
    "ONCOLOGY RESEARCH",
    "American Journal of Cancer Research",
    "MEDICAL SCIENCE MONITOR",
    "Oncology Letters",
    "Experimental and Therapeutic Medicine",
    "OncoTargets and Therapy",
    "ONCOLOGY REPORTS",
    "Molecular Medicine Reports",
    "INTERNATIONAL JOURNAL OF MOLECULAR MEDICINE",
    "JOURNAL OF INTERNATIONAL MEDICAL RESEARCH",
    "American Journal of Translational Research",
    "Journal of Biomaterials and Tissue Engineering",
    "Aging-US",
    "LIFE SCIENCES",
    "Journal of Clinical Medicine",
    "International Journal of Environmental Research and Public Health",
    "Acta Medica Mediterranea",
    "Symmetry-Basel",
    "electronics-switz",
    "sensors-basel",
    "sustainability-basel",
    "appl sci-basel",
    "mathematics-basel",
    "mob inf syst"
]

# 现在，你有一个包含所有期刊名称的列表"journals"
df = pd.read_csv("task3.csv")
# 将J9列和journals列表中的值都转换为小写
df['J9'] = df['J9'].str.lower()
journals = [journal.lower() for journal in journals]
# 使用不在journals列表中的值筛选DataFrame
filtered_df = df[~df['J9'].isin(journals)]
# 使用布尔索引筛选出PY列中大于或等于2008且小于2023的行
filtered_df = filtered_df[(filtered_df['PY'] >= 2008) & (filtered_df['PY'] < 2024)]
#删除空值所在的行
filtered_df.dropna(inplace=True)
filtered_df
# Out:
#        Unnamed: 0                                                 TI  \
# 0               0  Food tracking and blockchain-induced knowledge...
# 1               2  Intelligent design and implementation of block...
# 2               3  Technology for Social Good Foundations: A Pers...
# 4               5  Formalizing commitments using the event calcul...
# 5               7  Deep Generative Model for Inverse Design of Hi...
# ...           ...                                                ...
# 13101       17785  Secure and Scalable mHealth Data Management Us...
# 13102       17787  Research on Collaborative Governance of Smart ...
# 13103       17788  Understanding decentralized autonomous organiz...
# 13104       17789  Application of blockchain and smart contracts ...
# 13105       17790  Ban, Boom, and Echo! Entrepreneurship and Init...
#
#                                                       AF      PY  \
# 0                 Rainero, Christian|Modarelli, Giuseppe  2021.0
# 1      Ren, Qilei|Man, Ka Lok|Li, Muqing|Gao, Bingjie...  2019.0
# 2         Quayson, Matthew|Bai, Chunguang|Sarkis, Joseph  2021.0
# 4                        de Kruijff, Joost|Weigand, Hans  2021.0
# 5      Zhong, Chengquan|Zhang, Jingzi|Lu, Xiaoting|Zh...  2023.0
# ...                                                  ...     ...
# 13101  Motohashi, Tomomitsu|Hirano, Tomonobu|Okumura,...  2019.0
# 13102  Shan, Shaonan|Duan, Xia|Zhang, Yin|Zhang, Ting...  2021.0
# 13103  Augustin, Nils|Eckhardt, Andreas|de Jong, Alex...  2023.0
# 13104  Arunmozhi, Manimuthu|Venkatesh, V. G.|Arisian,...  2022.0
# 13105  Bellavitis, Cristiano|Cumming, Douglas|Vanacke...  2022.0
#
#                                                       RP  Z9  \
# 0      Modarelli, G (通讯作者)，Univ Torino, Dipartimento ...   7
# 1      Man, KL (通讯作者)，Xian Jiaotong Liverpool Univ, R...   6
# 2      Bai, CG (通讯作者)，Univ Elect Sci & Technol China,...  16
# 4      de Kruijff, J (通讯作者)，Tilburg Univ, Tilburg, Ne...   0
# 5      Lin, X (corresponding author), Harbin Inst Tec...   0
# ...                                                  ...  ..
# 13101  Ueno, T (通讯作者)，SUSMED Inc, Chuo Ku, Nihonbashi...  15
# 13102  Duan, X (通讯作者)，Capital Univ Econ & Business, S...   6
# 13103  Augustin, N (corresponding author), Univ Innsb...   0
# 13104  Arisian, S (通讯作者)，Trobe Univ, Trobe Business S...   1
# 13105  Bellavitis, C (通讯作者)，Syracuse Univ, Whitman Sc...  16
#
#                          J9  num-Authors  num-Male  num-Female  num-Unknown
# 0               brit food j            2         2           0            0
# 1      int j distrib sens n            5         0           0            5
# 2         ieee t eng manage            3         2           0            1
# 4                appl ontol            2         1           0            1
# 5      acs appl mater inter            8         1           0            7
# ...                     ...          ...       ...         ...          ...
# 13101    j med internet res            6         3           1            2
# 13102  discrete dyn nat soc            5         0           3            2
# 13103         electron mark            3         3           0            0
# 13104   transport res e-log            5         0           0            5
# 13105   entrep theory pract            3         3           0            0
#
# [12711 rows x 11 columns]

# %%
# 提取其余PY列
py_columns = [col for col in filtered_df.columns if col.startswith('PY')]

# 创建新的DataFrame，包含RP'和PY列
new_df = filtered_df[['J9'] + py_columns]

# 保存结果到新的CSV文件
new_df.to_csv('task2_期刊&年份.csv', index=False)

df1 = pd.read_csv('task2_期刊&年份.csv')
df1
# Out:
#                          J9      PY
# 0               brit food j  2021.0
# 1      int j distrib sens n  2019.0
# 2         ieee t eng manage  2021.0
# 3                appl ontol  2021.0
# 4      acs appl mater inter  2023.0
# ...                     ...     ...
# 12706    j med internet res  2019.0
# 12707  discrete dyn nat soc  2021.0
# 12708         electron mark  2023.0
# 12709   transport res e-log  2022.0
# 12710   entrep theory pract  2022.0
#
# [12711 rows x 2 columns]

# %%
df1['J9'].value_counts()[:15]
# Out:
# ieee internet things    563
# secur commun netw       265
# ieee t ind inform       222
# wirel commun mob com    200
# future gener comp sy    178
# cmc-comput mater con    159
# peer peer netw appl     145
# ieee t veh technol      140
# ieee network            138
# comput netw             128
# inform sciences         116
# comput commun           113
# multimed tools appl     111
# j supercomput           109
# concurr comp-pract e    100
# Name: J9, dtype: int64
