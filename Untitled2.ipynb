# %%
import pandas as pd

country0 = pd.read_csv("title_year_author_instation.csv", usecols = [2,3])

a = country0['RP']

i = 0
for countrys in a:
    RP_words = str(a[i]).split()
    country = RP_words[-1]
    country = country.rstrip('.')
    a[i] = country
    i += 1

country0['RP'] = a
# print(country0)
counts = pd.value_counts(country0['RP'])
print(counts[:10])
China = pd.value_counts(country0['RP'] == 'China')
country0.plot()
# Out:
# c:\users\think\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == "":
# China        2675
# USA           799
# Korea         572
# India         445
# England       347
# Australia     315
# Italy         257
# Spain         210
# Canada        193
# Germany       182
# Name: RP, dtype: int64
# <AxesSubplot:>
